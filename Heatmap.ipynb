# %%
import random
random.uniform(-300 * 10 ** (-6), 300 * 10 ** (-6))
# Out:
# -0.00017855686951624608

# %%
import pandas as pd
df = pd.read_csv("test2.csv")

# %%
import numpy as np
data = df.to_numpy()

# %%
print (data[0])
# Out:
# [7.10000000e+01 7.10000000e+01 7.10000000e+01 2.71300289e-02
#  2.67324916e-02 2.69130520e-02 9.77369414e-01 1.11454617e+00
#  1.45240370e-01 1.22612418e+00]

# %%
print(len(data))
print(data[0])
print(data[0][1])
# Out:
# 2000
# [7.10000000e+01 7.10000000e+01 7.10000000e+01 2.71300289e-02
#  2.67324916e-02 2.69130520e-02 9.77369414e-01 1.11454617e+00
#  1.45240370e-01 1.22612418e+00]
# 71.0

# %%
print(data[-1])
# Out:
# [1.61000000e+02 1.61000000e+02 2.61000000e+02 8.64530351e-03
#  8.70190973e-03 1.16819827e-02 4.83754200e-01 4.35365666e+00
#  3.94270980e+00 1.09262219e+01]

# %% [markdown]
# # Maksymalny błąd dla X, Y i Z

# %%
maxX = 0
maxY = 0
maxZ = 0
maxPos = 0
for row in data:
    if row[6] > maxX:
        maxX = row[6]
    if row[7] > maxY:
        maxY = row[7]
    if row[8] > maxZ:
        maxZ = row[8]
    if row[9] > maxPos:
        maxPos = row[9]
print((maxX, maxY, maxZ, maxPos))
# Out:
# (37.579799915667415, 35.837276787368616, 10.92587245161107, 20.596183400927877)

# %%
meanPos = 0.0
counter = 0
for row in data:
    if row[9] is not None:
        meanPos += row[9]
        counter += 1
meanPos = meanPos/counter
print(meanPos)
# Out:
# 6.633691849241842

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
for row in data:
    if row[9] is not None:
        p = ax.scatter(row[0], row[1], row[2], c=row[9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 2000

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
# Rysowanie błędu pozycji dla całego pomiaru
for row in data:
    if row[9] is not None:
        p = ax.scatter(row[0], row[1], row[2], c=row[9], norm=normalize)
plt.colorbar(p)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.005)
for i in range(0, 2000):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][3], norm=normalize)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.005)
for i in range(0, len(data), 10):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][3], norm=normalize)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.005)
for i in range(0, len(data), 10):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][4], norm=normalize)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.005)
for i in range(0, len(data), 10):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][5], norm=normalize)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.003)
for i in range(0, len(data), 10):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][3], norm=normalize)
