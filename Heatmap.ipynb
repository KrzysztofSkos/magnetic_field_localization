# %%
import matplotlib.pyplot as plt
import matplotlib.colors
import random
random.uniform(-300 * 10 ** (-6), 300 * 10 ** (-6))
# Out:
# 6.579080920078557e-05

# %%
import pandas as pd
df = pd.read_csv("test2.csv")

# %%
import numpy as np
data = df.to_numpy()

# %%
print (data[0])
# Out:
# [7.10000000e+01 7.10000000e+01 7.10000000e+01 2.68749057e-02
#  2.68159416e-02 2.70371802e-02 2.29413000e-01 5.44056767e-01
#  6.18925270e-01 1.34165641e+00]

# %%
print(len(data))
print(data[0])
print(data[0][1])
# Out:
# 2000
# [7.10000000e+01 7.10000000e+01 7.10000000e+01 2.68749057e-02
#  2.68159416e-02 2.70371802e-02 2.29413000e-01 5.44056767e-01
#  6.18925270e-01 1.34165641e+00]
# 71.0

# %%
print(data[-1])
# Out:
# [1.61000000e+02 1.61000000e+02 2.61000000e+02 8.75055621e-03
#  8.54597379e-03 1.19308163e-02 6.07270885e+00 8.35487270e+00
#  7.14862966e+00 1.52170205e+01]

# %% [markdown]
# # Maksymalny błąd dla X, Y i Z

# %%
maxX = 0
maxY = 0
maxZ = 0
maxPos = 0
for row in data:
    if row[6] > maxX:
        maxX = row[6]
    if row[7] > maxY:
        maxY = row[7]
    if row[8] > maxZ:
        maxZ = row[8]
    if row[9] > maxPos:
        maxPos = row[9]
print((maxX, maxY, maxZ, maxPos))
# Out:
# (37.595092295758725, 53.22531741032162, 12.42981062432456, 21.559354389748957)

# %%
import math
meanPos = 0.0
counter = 0
row9list = []

for row in data:
    if row[9] is not None and not math.isnan(row[9]):
        row9list.append(row[9])
        counter += 1

print(np.mean(row9list))
# Liczba punktów, które się w ogóle nie policzyły
print(counter)
# Łączna liczba nieudanych prób policzenia w dowolnej próbie: 5320
# Łączna liczba prób 2000 * 10 = 20000
# Out:
# 6.620959369749491
# 2000

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
for row in data:
    if row[9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(row[0], row[1], row[2], c=row[9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 2000

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (0, 200):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (200, 400):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (400, 600):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (600, 800):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (800, 1000):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (1000, 1200):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (1200, 1400):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (1400, 1600):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (1600, 1800):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
pointCount = 0
# Rysowanie błędu pozycji dla całego pomiaru
#for row in data:
for i in range (1800, 2000):
    if data[i][9] is not None and not math.isnan(row[9]):
#    if row[9] != 0:
        p = ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][9], norm=normalize)
        pointCount += 1
print(pointCount)
plt.colorbar(p)
# Out:
# 200

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0, vmax=maxPos)
# Rysowanie błędu pozycji dla całego pomiaru
for row in data:
    if row[9] is not None:
        p = ax.scatter(row[0], row[1], row[2], c=row[9], norm=normalize)
plt.colorbar(p)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Wykres Pola magnetycznego
current = 135000 # [A]
distance = np.linspace(1, 400, 1000)
flux = 2 * 10**(-7) * 100 * current / distance

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(distance, flux)
ax.vlines([100], -0.1, 2.7, color = 'green', linestyles = 'dashed', label = 'Measurement start')
ax.vlines([200, 300], -0.1, 2.7, color = 'red', linestyles = 'dashed', label = 'Measurement end')
plt.xlabel("Distance from magnet [cm]")
plt.ylabel("Magnetic flux [T]")
ax.grid()
#plt.vlines([71, 171, 271], 0, 400)

# %%
#Wykres Pola magnetycznego
current = 135000 # [A]
distance = np.linspace(90, 310, 800)
flux = 2 * 10**(-7) * 100 * current / distance

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(distance, flux)
ax.vlines([100], 0, 0.04, color = 'green', linestyles = 'dashed', label = 'Measurement start')
ax.vlines([200, 300], 0, 0.04, color = 'red', linestyles = 'dashed', label = 'Measurement end')
plt.xlabel("Distance from magnet [cm]")
plt.ylabel("Magnetic flux [T]")
ax.grid()
#plt.vlines([71, 171, 271], 0, 400)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# OX with red magnet
ax.plot((0,71), (0,0), (0,0), color = 'black')
ax.plot((71,171), (0,0), (0,0), color = 'red')
ax.plot((171,200), (0,0), (0,0), color = 'black')
ax.plot((195,200), (5,0), (0,0), color = 'black')
# OY with blue magnet
ax.plot((0,0), (0,71), (0,0), color = 'black')
ax.plot((0,0), (71,171), (0,0), color = 'blue')
ax.plot((0,0), (171,200), (0,0), color = 'black')
ax.plot((5,0), (195,200), (0,0), color = 'black')
# OZ with green magnet
ax.plot((0,0), (0,0), (0,71), color = 'black')
ax.plot((0,0), (0,0), (71,271), color = 'green')
ax.plot((0,0), (0,0), (271,300), color = 'black')
ax.plot((0,0), (5,0), (295,300), color = 'black')

# shadow
ax.plot((71,71), (71,171), (0,0), color = 'gray', linestyle = 'dashed')
ax.plot((71,171), (71,71), (0,0), color = 'gray', linestyle = 'dashed')
ax.plot((71,171), (171,171), (0,0), color = 'gray', linestyle = 'dashed')
ax.plot((171,171), (71,171), (0,0), color = 'gray', linestyle = 'dashed')

ax.plot((0,0), (71,171), (71,71), color = 'gray', linestyle = 'dashed')
ax.plot((0,0), (71,71), (71,271), color = 'gray', linestyle = 'dashed')
ax.plot((0,0), (171,171), (71,271), color = 'gray', linestyle = 'dashed')
ax.plot((0,0), (71,171), (271,271), color = 'gray', linestyle = 'dashed')

# connections
# ax.plot((171,171), (0,71), (0,0), color = 'gray', linestyle = 'dotted')
# ax.plot((71,71), (0,71), (0,0), color = 'gray', linestyle = 'dotted')
# ax.plot((0,71), (171,171), (0,0), color = 'gray', linestyle = 'dotted')
# ax.plot((0,71), (71,71), (0,0), color = 'gray', linestyle = 'dotted')

# ax.plot((0,0), (71,71), (0,71), color = 'gray', linestyle = 'dotted')
# ax.plot((0,0), (171,171), (0,71), color = 'gray', linestyle = 'dotted')
# ax.plot((0,0), (0,71), (71,71), color = 'gray', linestyle = 'dotted')
# ax.plot((0,0), (0,71), (271,271), color = 'gray', linestyle = 'dotted')

# Body area
ax.plot((71,71), (71,171), (71,71), color = 'black', linestyle = 'dashed')
ax.plot((71,171), (71,71), (71,71), color = 'black')
ax.plot((71,171), (171,171), (71,71), color = 'black', linestyle = 'dashed')
ax.plot((171,171), (71,171), (71,71), color = 'black')

ax.plot((71,71), (71,71), (71,271), color = 'black')
ax.plot((71,71), (171,171), (71,271), color = 'black', linestyle = 'dashed')
ax.plot((171,171), (171,171), (71,271), color = 'black')
ax.plot((171,171), (71,71), (71,271), color = 'black')

ax.plot((71,71), (71,171), (271,271), color = 'black')
ax.plot((71,171), (71,71), (271,271), color = 'black')
ax.plot((71,171), (171,171), (271,271), color = 'black')
ax.plot((171,171), (71,171), (271,271), color = 'black')

#Labels
ax.set_xlabel("O X")
ax.set_ylabel("O Y")
ax.set_zlabel("O Z")
# Out:
# Text(0.5, 0, 'O Z')

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
# lines = [[(0,0,0), (200,0,0)], [(0,0,0), (0,200,0)], [(0,0,0), (0,0,300)]]
# lc = mc.LineCollection3d(lines)
# ax.add_collection(lc)
# OX with red magnet
ax.plot((0,71), (0,0), (0,0), color = 'black')
ax.plot((71,171), (0,0), (0,0), color = 'red')
ax.plot((171,200), (0,0), (0,0), color = 'black')
# OY with blue magnet
ax.plot((0,0), (0,71), (0,0), color = 'black')
ax.plot((0,0), (71,171), (0,0), color = 'blue')
ax.plot((0,0), (171,200), (0,0), color = 'black')
# OZ with green magnet
ax.plot((0,0), (0,0), (0,71), color = 'black')
ax.plot((0,0), (0,0), (71,271), color = 'green')
ax.plot((0,0), (0,0), (271,300), color = 'black')

# shadow
# ax.plot((71,71), (71,171), (0,0), color = 'gray')
# ax.plot((71,171), (71,71), (0,0), color = 'gray')
# ax.plot((71,171), (171,171), (0,0), color = 'gray')
# ax.plot((171,171), (71,171), (0,0), color = 'gray')

# ax.plot((0,0), (71,171), (71,71), color = 'gray')
# ax.plot((0,0), (71,71), (71,271), color = 'gray')
# ax.plot((0,0), (171,171), (71,271), color = 'gray')
# ax.plot((0,0), (71,171), (271,271), color = 'gray')

# # connections
# ax.plot((171,171), (0,71), (0,0), color = 'gray', linestyle = 'dotted')
# ax.plot((71,71), (0,71), (0,0), color = 'gray', linestyle = 'dotted')
# ax.plot((0,71), (171,171), (0,0), color = 'gray', linestyle = 'dotted')
# ax.plot((0,71), (71,71), (0,0), color = 'gray', linestyle = 'dotted')

# ax.plot((0,0), (71,71), (0,71), color = 'gray', linestyle = 'dotted')
# ax.plot((0,0), (171,171), (0,71), color = 'gray', linestyle = 'dotted')
# ax.plot((0,0), (0,71), (71,71), color = 'gray', linestyle = 'dotted')
# ax.plot((0,0), (0,71), (271,271), color = 'gray', linestyle = 'dotted')

# Body area
ax.plot((71,71), (71,171), (71,71), color = 'black')
ax.plot((71,171), (71,71), (71,71), color = 'black')
ax.plot((71,171), (171,171), (71,71), color = 'black')
ax.plot((171,171), (71,171), (71,71), color = 'black')

ax.plot((71,71), (71,71), (71,271), color = 'black')
ax.plot((71,71), (171,171), (71,271), color = 'black')
ax.plot((171,171), (171,171), (71,271), color = 'black')
ax.plot((171,171), (71,71), (71,271), color = 'black')

ax.plot((71,71), (71,171), (271,271), color = 'black')
ax.plot((71,171), (71,71), (271,271), color = 'black')
ax.plot((71,171), (171,171), (271,271), color = 'black')
ax.plot((171,171), (71,171), (271,271), color = 'black')

#Labels
ax.set_xlabel("O X")
ax.set_ylabel("O Y")
ax.set_zlabel("O Z")
# Out:
# Text(0.5, 0, 'O Z')

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.005)
for i in range(0, 2000):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][3], norm=normalize)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.005)
for i in range(0, len(data), 10):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][3], norm=normalize)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.005)
for i in range(0, len(data), 10):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][4], norm=normalize)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.005)
for i in range(0, len(data), 10):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][5], norm=normalize)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
normalize = matplotlib.colors.Normalize(vmin=0.0001, vmax=0.003)
for i in range(0, len(data), 10):
    ax.scatter(data[i][0], data[i][1], data[i][2], c=data[i][3], norm=normalize)
